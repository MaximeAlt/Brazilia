# %% [markdown]
# # Exploration des données

# %% [markdown]
# ## Import & fonction

# %%
import pandas as pd
import numpy as np
import os
from pathlib import Path 
import missingno as msno
from tabulate import tabulate
from statistics import median, mean, quantiles
import pprint
import matplotlib.pyplot as plt 
import matplotlib.cm as cm
# %matplotlib inline
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from datetime import datetime, timedelta
from sklearn.cluster import KMeans
from geopy.geocoders import Nominatim
import geopy.distance
import folium
import geopy.distance
import prince
from sklearn import preprocessing
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn import cluster
from numpy import argmax
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline, make_pipeline
from yellowbrick.cluster import KElbowVisualizer
from yellowbrick.cluster import SilhouetteVisualizer, InterclusterDistance
from sklearn.metrics import davies_bouldin_score


plt.style.use('ggplot')
#pd.set_option('max_columns', 200)

# %% [markdown]
# ## Fonction

# %%
# Création d'un DF pour afficher les stats des données
def tstats (data) :
    output = []
    for col in data.columns:
    
        nonNull  = len(data) - np.sum(pd.isna(data[col]))
        nonNullprop = (nonNull / len(data[col]))*100
        unique = data[col].nunique()
        colType = str(data[col].dtype)
        output.append([col, colType, nonNull, round(nonNullprop, 1) , unique])
            
    
    df_stats = pd.DataFrame(output)
    df_stats.columns = ['nom colonne','dtype', 'valeur non null',"% de non null", 'nb_unique']

    print(tabulate(df_stats, headers='keys', tablefmt='psql'))
    
    
def diff_in_hours (date1, date2) :
    result_hour = (date1 - date2) / pd.Timedelta('1 hour')
    return result_hour


def filter_geo_brazil_lat(latitudes):
    filtered_latitudes = []
    default_lat = sum(latitudes) / len(latitudes)
    for lat in latitudes:
         if -33.75 <= lat <= 5.5:
            filtered_latitudes.append(lat)
         else : 
            filtered_latitudes.append(default_lat)            
    return filtered_latitudes


def filter_geo_brazil_lng(longitudes):
    filtered_longitudes = []
    default_lng = sum(longitudes) / len(longitudes)
    for lon in longitudes:
        if -74.5 <= lon <= -34.5:
            filtered_longitudes.append(lon)
        else : 
            filtered_longitudes.append(default_lng)
    return filtered_longitudes

# %% [markdown]
# ## Intégration des données et fusionner dans un dataframe

# %%
path = Path(os.getcwd()) 
p_parent = path.parent
p_customer = str(p_parent) + '\data\olist_customers_dataset.csv'
p_geo = str(p_parent) + '\data\olist_geolocation_dataset.csv'
p_order_item = str(p_parent) + '\data\olist_order_items_dataset.csv'
p_order_payment = str(p_parent) + '\data\olist_order_payments_dataset.csv'
p_order_review = str(p_parent) + '\data\olist_order_reviews_dataset.csv'
p_orders = str(p_parent) + '\data\olist_orders_dataset.csv'
p_products = str(p_parent) + '\data\olist_products_dataset.csv'
p_sellers = str(p_parent) + '\data\olist_sellers_dataset.csv'
p_category = str(p_parent) + '\data\product_category_name_translation_expanded.csv'

customer = pd.read_csv(p_customer)
geo = pd.read_csv(p_geo)
order_item = pd.read_csv(p_order_item)
order_payment = pd.read_csv(p_order_payment)
order_review = pd.read_csv(p_order_review)
orders = pd.read_csv(p_orders)
products = pd.read_csv(p_products)
sellers = pd.read_csv(p_sellers)
category = pd.read_csv(p_category)


#fusion avec .merge

df = orders.merge(customer, on="customer_id", how ='left')\
.merge(order_item, on= "order_id", how = 'left')\
.merge(order_payment, on ='order_id', how ='left')\
.merge(order_review, on ="order_id", how="left")\
.merge(sellers, on ='seller_id', how ="left")\
.merge(products, on = "product_id", how = 'left')\
.merge(category, on="product_category_name", how="left")\


# un erreur lié à la taille du df empeche d'y inclure les données géo
#.merge(geo, left_on ="customer_zip_code_prefix", right_on ='geolocation_zip_code_prefix', how ='inner')\
#.merge(geo, left_on ="seller_zip_code_prefix", right_on ='geolocation_zip_code_prefix', how ='inner')\

# on va créer un autre df pour traiter ces données :

# création de la base des vendeurs :
df_geo_seller = sellers.merge(geo, left_on ="seller_zip_code_prefix", right_on ='geolocation_zip_code_prefix', how ='inner')
#filtre des données hors brezil : 
df_geo_seller['geolocation_lat'] = filter_geo_brazil_lat(df_geo_seller['geolocation_lat'])
df_geo_seller['geolocation_lng'] = filter_geo_brazil_lng(df_geo_seller['geolocation_lng'])
#regroupement des données par vendeur : 
gr_geo_seller = df_geo_seller.groupby(['seller_id'], as_index=False).aggregate({
                'geolocation_lat':'mean',
                'geolocation_lng' : 'mean',
                }).rename(columns={"geolocation_lat": "seller_lat",
                            "geolocation_lng": "seller_lng",
                }) 

# création de la base des clients :
df_geo_customer = customer.merge(geo, left_on ="customer_zip_code_prefix", right_on ='geolocation_zip_code_prefix', how ='inner')
#filtre des données hors brezil :  
df_geo_customer['geolocation_lat'] = filter_geo_brazil_lat(df_geo_customer['geolocation_lat'])
df_geo_customer['geolocation_lng'] = filter_geo_brazil_lng(df_geo_customer['geolocation_lng'])
#regroupement des données par client unique : 
gr_geo_customer = df_geo_customer.groupby(['customer_unique_id'], as_index=False).aggregate({
                'geolocation_lat':'mean',
                'geolocation_lng' : 'mean',
                }).rename(columns={"geolocation_lat": "customer_lat",
                            "geolocation_lng": "customer_lng",
                })
# on ajoute ces nouveaux champ au df principale
df = df.merge(gr_geo_seller, left_on ="seller_id", right_on ='seller_id', how ='left')\
.merge(gr_geo_customer, left_on ="customer_unique_id", right_on ='customer_unique_id', how ='left')

#création d'un liste des nom de colonnes
cols = []

for col in df : 
    cols.append(col)

# transformation des colonnes date en format date

col_date = ['order_purchase_timestamp', 
            'order_approved_at', 
            'order_delivered_carrier_date', 
            'order_estimated_delivery_date',
            'review_creation_date',
            'review_answer_timestamp',
            'shipping_limit_date',
            'order_delivered_customer_date' 
           ]

# modification des type de colonne pour les zip code et les ID

df[col_date] = df[col_date].apply(pd.to_datetime)
df = df.astype({'customer_zip_code_prefix':'object',  'seller_zip_code_prefix' : 'object', "order_item_id": 'object'})

df= df.drop_duplicates()

tstats(df)
# Out:
# +----+-------------------------------+----------------+-------------------+-----------------+-------------+
# |    | nom colonne                   | dtype          |   valeur non null |   % de non null |   nb_unique |
# |----+-------------------------------+----------------+-------------------+-----------------+-------------|
# |  0 | order_id                      | object         |            119143 |           100   |       99441 |
# |  1 | customer_id                   | object         |            119143 |           100   |       99441 |
# |  2 | order_status                  | object         |            119143 |           100   |           8 |
# |  3 | order_purchase_timestamp      | datetime64[ns] |            119143 |           100   |       98875 |
# |  4 | order_approved_at             | datetime64[ns] |            118966 |            99.9 |       90733 |
# |  5 | order_delivered_carrier_date  | datetime64[ns] |            117057 |            98.2 |       81018 |
# |  6 | order_delivered_customer_date | datetime64[ns] |            115722 |            97.1 |       95664 |
# |  7 | order_estimated_delivery_date | datetime64[ns] |            119143 |           100   |         459 |
# |  8 | customer_unique_id            | object         |            119143 |           100   |       96096 |
# |  9 | customer_zip_code_prefix      | object         |            119143 |           100   |       14994 |
# | 10 | customer_city                 | object         |            119143 |           100   |        4119 |
# | 11 | customer_state                | object         |            119143 |           100   |          27 |
# | 12 | order_item_id                 | object         |            118310 |            99.3 |          21 |
# | 13 | product_id                    | object         |            118310 |            99.3 |       32951 |
# | 14 | seller_id                     | object         |            118310 |            99.3 |        3095 |
# | 15 | shipping_limit_date           | datetime64[ns] |            118310 |            99.3 |       93318 |
# | 16 | price                         | float64        |            118310 |            99.3 |        5968 |
# | 17 | freight_value                 | float64        |            118310 |            99.3 |        6999 |
# | 18 | payment_sequential            | float64        |            119140 |           100   |          29 |
# | 19 | payment_type                  | object         |            119140 |           100   |           5 |
# | 20 | payment_installments          | float64        |            119140 |           100   |          24 |
# | 21 | payment_value                 | float64        |            119140 |           100   |       29077 |
# | 22 | review_id                     | object         |            118146 |            99.2 |       98410 |
# | 23 | review_score                  | float64        |            118146 |            99.2 |           5 |
# | 24 | review_comment_title          | object         |             13989 |            11.7 |        4527 |
# | 25 | review_comment_message        | object         |             50245 |            42.2 |       36159 |
# | 26 | review_creation_date          | datetime64[ns] |            118146 |            99.2 |         636 |
# | 27 | review_answer_timestamp       | datetime64[ns] |            118146 |            99.2 |       98248 |
# | 28 | seller_zip_code_prefix        | object         |            118310 |            99.3 |        2246 |
# | 29 | seller_city                   | object         |            118310 |            99.3 |         611 |
# | 30 | seller_state                  | object         |            118310 |            99.3 |          23 |
# | 31 | product_category_name         | object         |            116601 |            97.9 |          73 |
# | 32 | product_name_lenght           | float64        |            116601 |            97.9 |          66 |
# | 33 | product_description_lenght    | float64        |            116601 |            97.9 |        2960 |
# | 34 | product_photos_qty            | float64        |            116601 |            97.9 |          19 |
# | 35 | product_weight_g              | float64        |            118290 |            99.3 |        2204 |
# | 36 | product_length_cm             | float64        |            118290 |            99.3 |          99 |
# | 37 | product_height_cm             | float64        |            118290 |            99.3 |         102 |
# | 38 | product_width_cm              | float64        |            118290 |            99.3 |          95 |
# | 39 | product_category_name_english | object         |            110377 |            92.6 |          55 |
# | 40 | metacategory                  | object         |            110377 |            92.6 |          10 |
# | 41 | seller_lat                    | float64        |            118045 |            99.1 |        2239 |
# | 42 | seller_lng                    | float64        |            118045 |            99.1 |        2239 |
# | 43 | customer_lat                  | float64        |            118825 |            99.7 |       15137 |
# | 44 | customer_lng                  | float64        |            118825 |            99.7 |       15138 |
# +----+-------------------------------+----------------+-------------------+-----------------+-------------+

# %% [markdown]
# ## Exploration des données

# %%
#Graph pour visualiser les NaN
msno.matrix(df, figsize=(32,16))
# Out:
# <AxesSubplot:>

# %% [markdown]
# On peut voir que les champs sont relativement bien remplis a l'exeption de "review_comment_title" et "review_comment_message"
#
# Certaines lignes semble également cumuler de nombreux NaN il faudrait investiguer un peu plus

# %%
msno.heatmap(df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# La heatmap de msno montre les corrélations entre données manquantes. Un 1 indique que si un information manque dans une colonne, alors elle manquera également dans l'autre. Le -1 serait une anticorrélation.
#
# On peut voir ici que lorsque order_delivered_customer_date est manquantes, order_delivered_carrier_date est souvent manquantes aussi.
#
#
# ## extraction des lignes suspectes
#
# Cette étape a été désactivé après rectification des merges.

# %%
#créer une liste avec les nom des colonnes
cols=[]
for col in df.columns:
    cols.append(col)

#stats des lignes avec des données manquantes : 
df['number_of_NaNs'] = df[cols].isna().sum(1)
df["number_of_NaNs"].describe()
# Out:
# count    119143.000000
# mean          1.889973
# std           2.235465
# min           0.000000
# 25%           1.000000
# 50%           2.000000
# 75%           2.000000
# max          32.000000
# Name: number_of_NaNs, dtype: float64

# %%
number_of_NaNs = df.number_of_NaNs.value_counts().sort_index()
print(number_of_NaNs)
# Out:
# 0     10893
# 1     35673
# 2     61650
# 3      3209
# 4      4061
# 5        81
# 6       941
# 7       743
# 8       968
# 9        40
# 10       18
# 11       14
# 12       17
# 13        1
# 14        1
# 23       40
# 24      468
# 25      255
# 26       50
# 27        1
# 29       14
# 30        4
# 32        1
# Name: number_of_NaNs, dtype: int64

# %%
#on voit que plusieurs centaines de lignes ont 20 ou + de donnée manquante sur leur ligne.
high_nan_row = df[df['number_of_NaNs'] >= 20]
msno.matrix(high_nan_row, figsize=(32,16))
# Out:
# <AxesSubplot:>

# %%
#Parmis les lignes où il manque le plus de données on peut voir que ce sont les colonnes provenant des fichiers 
#
#- order_item.csv 
#- product.csv
#- sellers.csv
#
#Au vu des relations entre les table, le problème viens probablement de la jointure entre order et order_item sur order_id
#(product et sellers dépendent de order_item)

#La colonne order_status semble avoir des valeurs spécifiques

high_nan_order_status = high_nan_row["order_status"].value_counts()
df_order_status = df["order_status"].value_counts()
ratio_order_status = high_nan_order_status /df_order_status *100

df_stats_order_status = pd.concat([df_order_status, high_nan_order_status, ratio_order_status], axis=1)
df_stats_order_status.columns = ['Order status_df', 'order_status_high_nan', 'ratio']
df_stats_order_status.head()
# Out:
#              Order status_df  order_status_high_nan      ratio
# delivered             115723                    NaN        NaN
# shipped                 1256                    1.0   0.079618
# canceled                 750                  180.0  24.000000
# unavailable              652                  645.0  98.926380
# invoiced                 378                    2.0   0.529101

# %%
#On peut voir que 98% des commandes qui ont le status 'unavailable' ont de nombreuses données manquantes, de meme que 24% des commandes 'canceled'
#
#Ces lignes pourronts être exclues si on cherche les 'bon clients', elle pourront éventuellement être prise en compte si on cherche les 'mauvais clients'
#
#Dans cette démarche on peurra étudier si des clients sont sur-représenté dans ces catégories  de "order status"

client_bad_orderstatus = df[(df['order_status'] == "canceled") | (df['order_status'] == "unavailable")]
tstats(client_bad_orderstatus)
# Out:
# +----+-------------------------------+----------------+-------------------+-----------------+-------------+
# |    | nom colonne                   | dtype          |   valeur non null |   % de non null |   nb_unique |
# |----+-------------------------------+----------------+-------------------+-----------------+-------------|
# |  0 | order_id                      | object         |              1402 |           100   |        1234 |
# |  1 | customer_id                   | object         |              1402 |           100   |        1234 |
# |  2 | order_status                  | object         |              1402 |           100   |           2 |
# |  3 | order_purchase_timestamp      | datetime64[ns] |              1402 |           100   |        1232 |
# |  4 | order_approved_at             | datetime64[ns] |              1245 |            88.8 |        1090 |
# |  5 | order_delivered_carrier_date  | datetime64[ns] |                80 |             5.7 |          74 |
# |  6 | order_delivered_customer_date | datetime64[ns] |                 7 |             0.5 |           6 |
# |  7 | order_estimated_delivery_date | datetime64[ns] |              1402 |           100   |         375 |
# |  8 | customer_unique_id            | object         |              1402 |           100   |        1220 |
# |  9 | customer_zip_code_prefix      | object         |              1402 |           100   |        1110 |
# | 10 | customer_city                 | object         |              1402 |           100   |         428 |
# | 11 | customer_state                | object         |              1402 |           100   |          25 |
# | 12 | order_item_id                 | object         |               577 |            41.2 |           6 |
# | 13 | product_id                    | object         |               577 |            41.2 |         442 |
# | 14 | seller_id                     | object         |               577 |            41.2 |         334 |
# | 15 | shipping_limit_date           | datetime64[ns] |               577 |            41.2 |         468 |
# | 16 | price                         | float64        |               577 |            41.2 |         327 |
# | 17 | freight_value                 | float64        |               577 |            41.2 |         342 |
# | 18 | payment_sequential            | float64        |              1402 |           100   |          10 |
# | 19 | payment_type                  | object         |              1402 |           100   |           5 |
# | 20 | payment_installments          | float64        |              1402 |           100   |          14 |
# | 21 | payment_value                 | float64        |              1402 |           100   |        1154 |
# | 22 | review_id                     | object         |              1368 |            97.6 |        1195 |
# | 23 | review_score                  | float64        |              1368 |            97.6 |           5 |
# | 24 | review_comment_title          | object         |               183 |            13.1 |         123 |
# | 25 | review_comment_message        | object         |               934 |            66.6 |         811 |
# | 26 | review_creation_date          | datetime64[ns] |              1368 |            97.6 |         364 |
# | 27 | review_answer_timestamp       | datetime64[ns] |              1368 |            97.6 |        1195 |
# | 28 | seller_zip_code_prefix        | object         |               577 |            41.2 |         308 |
# | 29 | seller_city                   | object         |               577 |            41.2 |         127 |
# | 30 | seller_state                  | object         |               577 |            41.2 |          12 |
# | 31 | product_category_name         | object         |               562 |            40.1 |          48 |
# | 32 | product_name_lenght           | float64        |               562 |            40.1 |          52 |
# | 33 | product_description_lenght    | float64        |               562 |            40.1 |         375 |
# | 34 | product_photos_qty            | float64        |               562 |            40.1 |           9 |
# | 35 | product_weight_g              | float64        |               577 |            41.2 |         189 |
# | 36 | product_length_cm             | float64        |               577 |            41.2 |          55 |
# | 37 | product_height_cm             | float64        |               577 |            41.2 |          56 |
# | 38 | product_width_cm              | float64        |               577 |            41.2 |          54 |
# | 39 | product_category_name_english | object         |               533 |            38   |          39 |
# | 40 | metacategory                  | object         |               533 |            38   |           9 |
# | 41 | seller_lat                    | float64        |               576 |            41.1 |         307 |
# | 42 | seller_lng                    | float64        |               576 |            41.1 |         307 |
# | 43 | customer_lat                  | float64        |              1393 |            99.4 |        1108 |
# | 44 | customer_lng                  | float64        |              1393 |            99.4 |        1110 |
# | 45 | number_of_NaNs                | int64          |              1402 |           100   |          17 |
# +----+-------------------------------+----------------+-------------------+-----------------+-------------+

# %%
# on peut voir que 1220 clients ont des commandes en status unknown ou canceled.

# %%
client_bad_orderstatus = client_bad_orderstatus.value_counts("customer_unique_id")

client_bad_orderstatus = (client_bad_orderstatus_nb.groupby(['customer_unique_id', 'review_id'], as_index=False).count()
            .groupby('customer_unique_id')['review_id'].count())
print(client_review.value_counts().sort_index())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 3>()
#       1 client_bad_orderstatus = client_bad_orderstatus.value_counts("customer_unique_id")
# ----> 3 client_bad_orderstatus = (client_bad_orderstatus_nb.groupby(['customer_unique_id', 'review_id'], as_index=False).count()
#       4             .groupby('customer_unique_id')['review_id'].count())
#       5 print(client_review.value_counts().sort_index())
#
# NameError: name 'client_bad_orderstatus_nb' is not defined

# %% [markdown]
# ### Nombre de commande par client

# %%
client_order = (df.groupby(['order_id', 'customer_unique_id'], as_index=False).count()
            .groupby('customer_unique_id')['order_id'].count())
print(client_order.value_counts().sort_index())

# %% [markdown]
# On peut voir que la majorité des clients ont commandé qu'une fois. Il faudrait sans doute analyser les clients ayant commandé de multiples fois séparément.

# %% [markdown]
# ### Nombre de review par client

# %%
client_review = (df.groupby(['customer_unique_id', 'review_id'], as_index=False).count()
            .groupby('customer_unique_id')['review_id'].count())
print(client_review.value_counts().sort_index())
# Out:
# 1     92659
# 2      2503
# 3       172
# 4        28
# 5         7
# 6         6
# 7         3
# 8         1
# 17        1
# Name: review_id, dtype: int64

# %% [markdown]
# On peut voir que la majorité des clients n'ont laissé qu'une review.

# %% [markdown]
# ## Nombre group by Customer

# %%
gr_customer = df.groupby(['customer_unique_id'], as_index=False).aggregate({
                'customer_unique_id' : 'nunique',
                'order_id':'nunique',
                'price' : 'sum',
                'review_id':'nunique',
                'review_score':'mean',
                'product_id' : 'count',
                'seller_id' : 'nunique'
                })

round(gr_customer.describe())
# Out:
#        customer_unique_id  order_id    price  review_id  review_score  \
# count             96096.0   96096.0  96096.0    96096.0       95380.0
# mean                  1.0       1.0    149.0        1.0           4.0
# std                   0.0       0.0    249.0        0.0           1.0
# min                   1.0       1.0      0.0        0.0           1.0
# 25%                   1.0       1.0     48.0        1.0           4.0
# 50%                   1.0       1.0     90.0        1.0           5.0
# 75%                   1.0       1.0    160.0        1.0           5.0
# max                   1.0      17.0  13440.0       17.0           5.0
#
#        product_id  seller_id
# count     96096.0    96096.0
# mean          1.0        1.0
# std           1.0        0.0
# min           0.0        0.0
# 25%           1.0        1.0
# 50%           1.0        1.0
# 75%           1.0        1.0
# max          75.0       10.0

# %% [markdown]
# Les 96096 clients ont chacun :
# - réalisé entre 1 et 17 commande,
# - pour un total de 1 à 75 produits
# - chez 0 à 10 vendeurs différents
# - dépensé un montant compris entre 0 et 13440,
# - laissé entre 0 et 17 review
# - avec une moyenne comprise entre 1 et 5

# %% [markdown]
# ## Nombre group by Category

# %%
gr_category = df.groupby(['metacategory']).aggregate({
    
    'price' : 'sum',
    'customer_unique_id' : 'nunique',
    'review_id':'nunique',
    'review_score':'mean',
    'order_id':'nunique',
    'order_item_id' :'count',
    'product_id' : 'count',
    'seller_id' : 'nunique'
    })


print(gr_category.sort_values(by=['price'], ascending =False ))
# Out:
#                         price  customer_unique_id  review_id  review_score  \
# metacategory
# Home supply        4312839.25               30875      31469      3.959494
# Health and beauty  2153403.51               14654      14799      4.109266
# High tech          1986695.73               15065      15173      3.958899
# Other              1876610.87               11965      12008      4.118235
# Fashion            1402743.88                6574       6612      4.061749
# Sport supply       1029603.88                7515       7656      4.107470
# Tools               362647.91                1924       1921      4.035788
# Books               156215.13                 998       1002      4.359266
# Food and Drinks      69505.72                 961        967      4.192405
# Art                   6961.26                  65         66      4.216216
#
#                    order_id  order_item_id  product_id  seller_id
# metacategory
# Home supply           31797          40868       40868       1274
# Health and beauty     14897          16864       16864        784
# High tech             15291          17858       17858        491
# Other                 12091          13520       13520        835
# Fashion                6658           7376        7376        168
# Sport supply           7720           9004        9004        481
# Tools                  1935           2455        2455        267
# Books                  1007           1151        1151        107
# Food and Drinks         974           1207        1207        114
# Art                      65             74          74         14

# %% [markdown]
# On peut voir que les catégories ayant généré le plus de ventes sont :
#  - health_beauty :
#      - 2153403.51 de revenu
#      - 14897 commande
#      - 14654 clients différents
#      -16864 produits au total
#      -784 vendeurs différents
#      -14799 reviews à 4.1 de moyenne,

# %%
### Exploration valeur numérique
###a voir la pertinance


#   df_num= df.select_dtypes(include=["int64", "float64"])
#   #df_num.drop(columns=['customer_zip_code_prefix', 'seller_zip_code_prefix', "order_item_id"], inplace = True)
#   output = []
#   for col in df_num.columns:
#   
#       nonNull  = len(df) - np.sum(pd.isna(df[col]))
#       nonNullprop = (nonNull / len(df[col]))*100
#       unique = df[col].nunique()
#       colType = str(df[col].dtype)
#       min = np.min(df[col])
#       max = np.max(df[col])
#       moyenne = round(np.nanmean(df[col]),2)
#       quantile25 = np.nanquantile(df[col],0.25)
#       quantile5 = np.nanquantile(df[col],0.5)
#       quantile75 = np.nanquantile(df[col],0.5)
#       std = round(np.nanstd(df[col]),2)
#       var = round(np.nanvar(df[col]),2)
#       output.append([col, min, max, quantile25, quantile5, quantile75, std, var]) 
#           
#   df_stats = pd.DataFrame(output)
#   df_stats.columns = ['nom colonne', "min", "max", 'quantile.25', 'median', 'quantile.75', 'std', 'var']
#   
#   
#   pp = pprint.PrettyPrinter(indent=4)
#   #print(tabulate(df_stats, headers='keys', tablefmt='psql'))
#   pp.pprint(df_stats)

# %%
#   review_score_heatmap = df.corr()['review_score'].to_frame().sort_values('review_score', ascending=False)
#   review_score_heatmap = review_score_heatmap.drop(['review_score'])
#   sns.heatmap(review_score_heatmap, annot=True)
#   plt.title("Order_ID Correaltions to Review Score")
#   plt.show()

# %%
#  sns.pairplot(df)

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# Dans cette partie, nous allons créer de nouvelles variables à partir des données de base qui pourront nous aider a mieux comprendre les différents comportement des clients.
#
# conseil :
# - fréquence Achat
# - prix du panier moyen
# - moyen paiement
# - delais livraison
# - position acheteur / vendeur

# %% [markdown]
# ### Moyen paiement

# %% [markdown]
# La table order_payments nous informe sur les modalité de payment:
# - payment_sequential nous donne tous les payements effectés pour une commande
# - payment_type nous donne le moyen de payment
# - payment_installments nous donne l'étalement des payement( en mois probablement)
# - payment_value nous donne la valeur du payement

# %%
df_pay_method= df[['customer_unique_id', 'payment_value', "payment_type"]].set_index('customer_unique_id')
pay_method= pd.get_dummies(df_pay_method["payment_type"],prefix='pay_type', columns = ['payment_type']).copy()

# %%
gr_pay_method = pay_method.groupby(['customer_unique_id']).aggregate({
    'pay_type_boleto' : 'sum',
    'pay_type_credit_card' : 'sum',
    'pay_type_debit_card' : 'sum',
    'pay_type_not_defined' : 'sum',
    'pay_type_voucher' : 'sum',              
    }).reset_index()

# %%
df_pay_method.drop(columns='payment_type', inplace=True)
df_pay_method = df_pay_method.groupby(['customer_unique_id']).aggregate({
    'payment_value' : 'sum'}).reset_index()

# %%
gr_pay_method = gr_pay_method.merge(df_pay_method, on='customer_unique_id', how="left")
gr_pay_method.describe()
# Out:
#        pay_type_boleto  pay_type_credit_card  pay_type_debit_card  \
# count     96096.000000          96096.000000         96096.000000
# mean          0.241321              0.913420             0.017753
# std           0.580622              0.746106             0.153889
# min           0.000000              0.000000             0.000000
# 25%           0.000000              1.000000             0.000000
# 50%           0.000000              1.000000             0.000000
# 75%           0.000000              1.000000             0.000000
# max          20.000000             24.000000             7.000000
#
#        pay_type_not_defined  pay_type_voucher  payment_value
# count          96096.000000      96096.000000   96096.000000
# mean               0.000031          0.067276     214.157343
# std                0.005587          0.572776     644.891987
# min                0.000000          0.000000       0.000000
# 25%                0.000000          0.000000      64.000000
# 50%                0.000000          0.000000     113.340000
# 75%                0.000000          0.000000     203.422500
# max                1.000000         75.000000  109312.640000

# %% [markdown]
# Comparaison item_value + feight_value et payement_value

# %%
df_pay_completion = df[['customer_unique_id',
                       'order_id', 
                       'freight_value',
                       'price',
                       'payment_value']].copy()
df_pay_completion['total_value'] = df_pay_completion['price'] + df_pay_completion['freight_value']
df_pay_completion.head()
# Out:
#                       customer_unique_id                          order_id  \
# 63195   0000366f3b9a7992bf8c76cfdf3221e2  e22acc9c116caa3f2b7121bbb380d08e
# 88385   0000b849f77a49e4a4ce2b2a4ca5be3f  3594e05a005ac4d06a72673270ef9ec9
# 31704   0000f46a3911fa3c0805444483337064  b33ec3b699337181488304f362a6b734
# 117980  0000f6ccb0745a6a4b88665a16c9f078  41272756ecddd9a9ed0180413cc22fb6
# 49813   0004aac84e0df4da2b147fca70cf8255  d957021f1127559cd947b62533f484f7
#
#         freight_value   price  payment_value  total_value
# 63195           12.00  129.90         141.90       141.90
# 88385            8.29   18.90          27.19        27.19
# 31704           17.22   69.00          86.22        86.22
# 117980          17.63   25.99          43.62        43.62
# 49813           16.89  180.00         196.89       196.89

# %%
gr_pay_completion = df_pay_completion.groupby(['customer_unique_id','order_id' ]).sum().reset_index()
gr_pay_completion.head()
# Out:
#                  customer_unique_id                          order_id  \
# 0  0000366f3b9a7992bf8c76cfdf3221e2  e22acc9c116caa3f2b7121bbb380d08e
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f  3594e05a005ac4d06a72673270ef9ec9
# 2  0000f46a3911fa3c0805444483337064  b33ec3b699337181488304f362a6b734
# 3  0000f6ccb0745a6a4b88665a16c9f078  41272756ecddd9a9ed0180413cc22fb6
# 4  0004aac84e0df4da2b147fca70cf8255  d957021f1127559cd947b62533f484f7
#
#    freight_value   price  payment_value  total_value
# 0          12.00  129.90         141.90       141.90
# 1           8.29   18.90          27.19        27.19
# 2          17.22   69.00          86.22        86.22
# 3          17.63   25.99          43.62        43.62
# 4          16.89  180.00         196.89       196.89

# %%
tstats(gr_pay_completion)
# Out:
# +----+--------------------+---------+-------------------+-----------------+-------------+
# |    | nom colonne        | dtype   |   valeur non null |   % de non null |   nb_unique |
# |----+--------------------+---------+-------------------+-----------------+-------------|
# |  0 | customer_unique_id | object  |             99441 |             100 |       96096 |
# |  1 | order_id           | object  |             99441 |             100 |       99441 |
# |  2 | freight_value      | float64 |             99441 |             100 |        8441 |
# |  3 | price              | float64 |             99441 |             100 |        8192 |
# |  4 | payment_value      | float64 |             99441 |             100 |       30342 |
# |  5 | total_value        | float64 |             99441 |             100 |       32069 |
# +----+--------------------+---------+-------------------+-----------------+-------------+

# %%
result = gr_pay_completion['total_value'] - gr_pay_completion['payment_value']
result.info()
# Out:
# <class 'pandas.core.series.Series'>
# MultiIndex: 99441 entries, ('00010242fe8c5a6d1ba2dd792cb16214', '871766c5855e863f6eccc05f988b23cb') to ('fffe41c64501cc87c801fd61db3f6244', 'cd76a00d8e3ca5e6ab9ed9ecb6667ac4')
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 99441 non-null  float64
# dtypes: float64(1)
# memory usage: 3.0+ MB

# %% [markdown]
# ### Prix panier moyen

# %%
#avg_basket = df['price'].sum() / df['order_id'].nunique()

gr_avg_customer_basket = df.groupby(['customer_unique_id']).aggregate({
    'order_id' : 'nunique',
    'payment_value' : 'sum'
    }).reset_index()

gr_avg_customer_basket['avg_bask_price'] = gr_avg_customer_basket['payment_value'] / gr_avg_customer_basket['order_id']
gr_avg_customer_basket.describe()
# Out:
#            order_id  payment_value  avg_bask_price
# count  96096.000000   96096.000000    96096.000000
# mean       1.034809     214.157343      206.066785
# std        0.214384     644.891987      619.050852
# min        1.000000       0.000000        0.000000
# 25%        1.000000      64.000000       63.270000
# 50%        1.000000     113.340000      111.020000
# 75%        1.000000     203.422500      196.360000
# max       17.000000  109312.640000   109312.640000

# %% [markdown]
# ### Buying frequency

# %%
# Ordrer the data set by customer ID and Ordering date: 
df = df.sort_values(by=['customer_unique_id', 'order_purchase_timestamp'])

# Calcul of time diff between 2 successive order :
df['buy_date_diff'] = df.groupby('customer_unique_id')['order_purchase_timestamp'].diff()

# Convert into days and set to 0 all the customer who only ordered once
df['buy_freq'] = df['buy_date_diff'].dt.days
df['buy_freq'] = df['buy_freq'].fillna(0)

# group by to get the average frequency per customer

avg_buy_freq = df.groupby('customer_unique_id')['buy_freq']\
    .mean().reset_index()\
    .rename(columns={'buy_freq': 'Avg Buying Frequency'})

# the result is the average number of days between 2 order for a customer.
avg_buy_freq.describe()
# Out:
#        Avg Buying Frequency
# count          96096.000000
# mean               1.121853
# std               10.847308
# min                0.000000
# 25%                0.000000
# 50%                0.000000
# 75%                0.000000
# max              304.000000

# %%
# approbation duration in hours
df["tapproved"] = diff_in_hours(df['order_approved_at'], df['order_purchase_timestamp'])

# duration diff between ETA et real arrival time in hours - negatif means late, positif means early
df['testimate'] = diff_in_hours(df['order_estimated_delivery_date'], df['order_delivered_customer_date'])

# total duration between client order and delivery
df['totaltime'] = diff_in_hours(df['order_delivered_customer_date'], df['order_purchase_timestamp'])

# duration between delivery and review
df['treview'] =  diff_in_hours(df['review_creation_date'], df['order_delivered_customer_date'])

# %% [markdown]
# ### Transport feature

# %%
print(cols)
# Out:
# ['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date', 'customer_unique_id', 'customer_zip_code_prefix', 'customer_city', 'customer_state', 'order_item_id', 'product_id', 'seller_id', 'shipping_limit_date', 'price', 'freight_value', 'payment_sequential', 'payment_type', 'payment_installments', 'payment_value', 'review_id', 'review_score', 'review_comment_title', 'review_comment_message', 'review_creation_date', 'review_answer_timestamp', 'seller_zip_code_prefix', 'seller_city', 'seller_state', 'product_category_name', 'product_name_lenght', 'product_description_lenght', 'product_photos_qty', 'product_weight_g', 'product_length_cm', 'product_height_cm', 'product_width_cm', 'product_category_name_english', 'metacategory', 'seller_lat', 'seller_lng', 'customer_lat', 'customer_lng']

# %%
#Du ratio du prix lié au transport
df['ratio_transport_cost'] = df["payment_value"] / df["freight_value"]

# %%
## a revoir pour eviter les NaN est les inf.

#for label, row in df.iterrows() : 
#    if pd.notna(row['seller_lat']) & pd.notna(row['seller_lng']) & pd.notna(row['customer_lat']) & pd.notna(row['customer_lng']):
#        customer_location = [row['seller_lat'], row['seller_lng']]
#        seller_location = [row['customer_lat'], row['customer_lng']]
#        df.loc [label, "delivery_distance"] = geopy.distance.geodesic(customer_location, seller_location).km
#df["transport_cost_per_km"] = df["freight_value"] / df["delivery_distance"]

# %%
## on calcul la distance de livraison : distance coordonnées vendeur et acheteur

for label, row in df.iterrows() : 
    if pd.notna(row['seller_lat']) & pd.notna(row['seller_lng']) & pd.notna(row['customer_lat']) & pd.notna(row['customer_lng']):
        customer_location = [row['seller_lat'], row['seller_lng']]
        seller_location = [row['customer_lat'], row['customer_lng']]
        distance = geopy.distance.geodesic(customer_location, seller_location).km
        if distance != [np.nan, np.inf, -np.inf] :
            df.loc [label, "delivery_distance"] = distance
        else : 
            df.loc [label, "delivery_distance"] = 0

# %%
## Cout moyen par km : 
mean_cost_per_km = df["delivery_distance"].sum()/df["freight_value"].sum()       
## cout du transport par km :
df["transport_cost_per_km"] = df["delivery_distance"]/df["freight_value"]

##gestion des nan, inf en remplacant par le cout moyen sur l'ensemble du dataset.
for label, row in df.iterrows() : 
    value_test = row["transport_cost_per_km"]
    if ((np.isnan(value_test) | np.isinf(value_test) | np.isneginf(value_test)).any().any()) :
        df["transport_cost_per_km"] = mean_cost_per_km

# %% [markdown]
# ## Order status feature

# %%
df['order_status'].describe()
# Out:
# count        119143
# unique            8
# top       delivered
# freq         115723
# Name: order_status, dtype: object

# %%
subset_order_status = df[["customer_unique_id", "order_status"]]

# %%
dm_order_status = pd.get_dummies(subset_order_status, columns=['order_status'])

# %%
gr_order_status = dm_order_status.groupby(['customer_unique_id']).aggregate({
    'order_status_approved' : 'sum',
    'order_status_canceled' : 'sum',
    'order_status_created':'sum',
    'order_status_delivered':'sum',
    'order_status_invoiced':'sum',
    'order_status_processing' :'sum',
    'order_status_shipped' : 'sum',
    'order_status_unavailable' : 'sum'
    })

# %%
gr_order_status["ratio_delivered"] = gr_order_status["order_status_delivered"] /     \
np.sum(gr_order_status,axis=1)

# %%
notOnlyDelivered = gr_order_status[gr_order_status["ratio_delivered"] != 1]

# %%
gr_order_status = dm_order_status.groupby(['customer_unique_id']).aggregate({
    'order_status_canceled' : 'sum',
    'order_status_delivered':'sum',
    'order_status_unavailable' : 'sum'
    })

# %%
gr_order_status["ratio_delivered"] = gr_order_status["order_status_delivered"] /     \
np.sum(gr_order_status,axis=1)

# %%
notOnlyDelivered = gr_order_status[gr_order_status["ratio_delivered"] != 1]
notOnlyDelivered.info()

# %% [markdown]
# # Customer Focus:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119143 entries, 63195 to 83699
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       119143 non-null  object
#  1   customer_id                    119143 non-null  object
#  2   order_status                   119143 non-null  object
#  3   order_purchase_timestamp       119143 non-null  datetime64[ns]
#  4   order_approved_at              118966 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   117057 non-null  datetime64[ns]
#  6   order_delivered_customer_date  115722 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  119143 non-null  datetime64[ns]
#  8   customer_unique_id             119143 non-null  object
#  9   customer_zip_code_prefix       119143 non-null  object
#  10  customer_city                  119143 non-null  object
#  11  customer_state                 119143 non-null  object
#  12  order_item_id                  118310 non-null  object
#  13  product_id                     118310 non-null  object
#  14  seller_id                      118310 non-null  object
#  15  shipping_limit_date            118310 non-null  datetime64[ns]
#  16  price                          118310 non-null  float64
#  17  freight_value                  118310 non-null  float64
#  18  payment_sequential             119140 non-null  float64
#  19  payment_type                   119140 non-null  object
#  20  payment_installments           119140 non-null  float64
#  21  payment_value                  119140 non-null  float64
#  22  review_id                      118146 non-null  object
#  23  review_score                   118146 non-null  float64
#  24  review_comment_title           13989 non-null   object
#  25  review_comment_message         50245 non-null   object
#  26  review_creation_date           118146 non-null  datetime64[ns]
#  27  review_answer_timestamp        118146 non-null  datetime64[ns]
#  28  seller_zip_code_prefix         118310 non-null  object
#  29  seller_city                    118310 non-null  object
#  30  seller_state                   118310 non-null  object
#  31  product_category_name          116601 non-null  object
#  32  product_name_lenght            116601 non-null  float64
#  33  product_description_lenght     116601 non-null  float64
#  34  product_photos_qty             116601 non-null  float64
#  35  product_weight_g               118290 non-null  float64
#  36  product_length_cm              118290 non-null  float64
#  37  product_height_cm              118290 non-null  float64
#  38  product_width_cm               118290 non-null  float64
#  39  product_category_name_english  110377 non-null  object
#  40  metacategory                   110377 non-null  object
#  41  seller_lat                     118045 non-null  float64
#  42  seller_lng                     118045 non-null  float64
#  43  customer_lat                   118825 non-null  float64
#  44  customer_lng                   118825 non-null  float64
#  45  tapproved                      118966 non-null  float64
#  46  testimate                      115722 non-null  float64
#  47  totaltime                      115722 non-null  float64
#  48  treview                        114861 non-null  float64
#  49  buy_date_diff                  23047 non-null   timedelta64[ns]
#  50  buy_freq                       119143 non-null  float64
#  51  delivery_distance              117733 non-null  float64
#  52  transport_cost_per_km          119143 non-null  float64
# dtypes: datetime64[ns](8), float64(24), object(20), timedelta64[ns](1)
# memory usage: 53.1+ MB

# %%
rd_test1 = df.copy().groupby(['customer_unique_id'], as_index=True).aggregate({
                'order_id':'nunique',
                'price' : 'sum',
                'review_id':'nunique',
                'review_score':'mean',
                'product_id' : 'count',
                'seller_id' : 'nunique',
                'tapproved' : 'mean',
                'testimate' : 'mean',
                'totaltime' : 'mean',
                'treview' : 'mean',
                'buy_freq' : 'mean',
                'delivery_distance' : 'mean',
                'ratio_transport_cost' : 'mean',
                'transport_cost_per_km' : 'mean'
                }).rename(columns={"customer_unique_id": "customer_unique_id",
                            "order_id": "nb_order",
                            "price": "total_spend", 
                            "review_id" : "nb_review", 
                            "review_score": "mean_review", 
                            "product_id": "total_nb_product", 
                            "seller_id": "total_nb_sellers",
                            "tapproved": "temps_approbation",
                            "testimate": "erreur_estimation_livraison",
                            "totaltime": "temps_commande_livraison",
                            "treview": "temps_livraison_review"})

# %%
rd_test1= rd_test1.merge(gr_pay_method, on="customer_unique_id", how='left').merge (gr_avg_customer_basket, on="customer_unique_id", how='left')
rd_test1.drop(columns=['price', 'order_id'], inplace = True)

# %%
rd_test1.head()
# Out:
#                  customer_unique_id  nb_order  total_spend  nb_review  \
# 0  0000366f3b9a7992bf8c76cfdf3221e2         1       129.90          1
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f         1        18.90          1
# 2  0000f46a3911fa3c0805444483337064         1        69.00          1
# 3  0000f6ccb0745a6a4b88665a16c9f078         1        25.99          1
# 4  0004aac84e0df4da2b147fca70cf8255         1       180.00          1
#
#    mean_review  total_nb_product  total_nb_sellers  temps_approbation  \
# 0          5.0                 1                 1           0.247500
# 1          4.0                 1                 1           7.238056
# 2          3.0                 1                 1           0.000000
# 3          4.0                 1                 1           0.326667
# 4          5.0                 1                 1           0.352778
#
#    erreur_estimation_livraison  temps_commande_livraison  ...  buy_freq  \
# 0                    99.189722                153.869444  ...       0.0
# 1                   101.955000                 78.854167  ...       0.0
# 2                    33.353611                617.562222  ...       0.0
# 3                   266.615278                480.890000  ...       0.0
# 4                   168.851111                315.387222  ...       0.0
#
#    delivery_distance  ratio_transport_cost  transport_cost_per_km  \
# 0         110.496092             10.825000              29.586016
# 1          22.190341              2.279855              29.586016
# 2         515.379484              4.006969              29.586016
# 3        2468.983992              1.474192              29.586016
# 4         154.744091             10.657194              29.586016
#
#    pay_type_boleto  pay_type_credit_card  pay_type_debit_card  \
# 0                0                     1                    0
# 1                0                     1                    0
# 2                0                     1                    0
# 3                0                     1                    0
# 4                0                     1                    0
#
#    pay_type_not_defined  pay_type_voucher  avg_bask_price
# 0                     0                 0          129.90
# 1                     0                 0           18.90
# 2                     0                 0           69.00
# 3                     0                 0           25.99
# 4                     0                 0          180.00
#
# [5 rows x 21 columns]

# %%
corr = rd_test1.corr()
# Set up the matplotlib plot configuration
f, ax = plt.subplots(figsize=(12, 10))
# Generate a mask for upper traingle
mask = np.triu(np.ones_like(corr, dtype=bool))
# Configure a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)
# Draw the heatmap
sns.heatmap(corr, annot=True, mask = mask, cmap=cmap)
# Out:
# <AxesSubplot:>

# %%
msno.matrix(rd_test1, figsize=(32,16))
#rd_test1= rd_test1.dropna()
# Out:
# <AxesSubplot:>

# %%
#nettoyage des valeurs manquantes :

# %% [markdown]
# ## Classification Sub Set (CSS)

# %%
css1 = df.copy().groupby(['customer_unique_id'], as_index=True).aggregate({

                'price' : 'sum',
                'review_id':'nunique',
                'review_score':'mean',
                'seller_id' : 'nunique',
                'testimate' : 'mean',
                'totaltime' : 'mean',
                'buy_freq' : 'mean',

                }).rename(columns={"customer_unique_id": "customer_unique_id",
                            "order_id": "nb_order",
                            "price": "total_spend", 
                            "review_score": "mean_review", 
                            "product_id": "total_nb_product", 
                            "seller_id": "total_nb_sellers",
                            "testimate": "erreur_estimation_livraison",
                            "totaltime": "temps_commande_livraison"})

# %%
css1.to_csv(r'C:\Users\Maxime.ALTER\ProjetFinal\data\kmean_Data.csv')

# %%
ccs2_features = ['order_id','order_status', 'customer_unique_id', 'customer_city',
                'customer_state', 'product_id', 'seller_id', 'seller_city', 'seller_state', 'price',
                'freight_value', 'product_category_name_english', 'review_score', 'metacategory', 'buy_freq',
                'tapproved', 'testimate', 'totaltime', 'treview', 'delivery_distance',
                'transport_cost_per_km']

# %%
css2 = df[ccs_features2].copy()

css2.to_csv(r'C:\Users\Maxime.ALTER\ProjetFinal\data\css2.csv', index = False)

# %%
css3_features = ['order_id','order_status', 'customer_unique_id', 'customer_city',
                'customer_state', 'product_id', 'seller_id', 'seller_city', 'seller_state', 'price',
                'freight_value', 'product_category_name_english', 'review_score', 'metacategory', 'buy_freq',
                'tapproved', 'testimate', 'totaltime', 'treview', 'delivery_distance',
                'transport_cost_per_km']

# %%
css3_features = ['customer_unique_id','buy_freq', 'totaltime', 'delivery_distance']
css3 = df[css3_features].copy()

# %%
css3 = df.copy()
css3 =css3.groupby(['customer_unique_id']).aggregate({
                'buy_freq' : 'sum',
                'totaltime':'nunique',
                'delivery_distance':'mean',
                'testimate' : 'mean'
                }).rename(columns={"totaltime": "nb_heure_livraison",
                                   'testimate':'nombre_heure_ecart_predict'})
css3 =ccs3.merge(gr_avg_customer_basket, on= 'customer_unique_id', how = 'left')\
          .merge(gr_pay_method, on ='customer_unique_id', how='left')

# %%
css3.describe()
# Out:
#            buy_freq  nb_heure_livraison  delivery_distance  \
# count  96096.000000        96096.000000       94954.000000
# mean       2.710238            1.003954         601.277039
# std       25.381901            0.268438         591.818942
# min        0.000000            0.000000           0.000000
# 25%        0.000000            1.000000         189.724342
# 50%        0.000000            1.000000         434.314073
# 75%        0.000000            1.000000         798.237222
# max      632.000000           15.000000        3565.223556
#
#        nombre_heure_ecart_predict    order_id_x       price_x  \
# count                93356.000000  96096.000000  96096.000000
# mean                   267.675872      1.034809    148.535836
# std                    243.468266      0.214384    249.358758
# min                  -4535.401944      1.000000      0.000000
# 25%                    153.419236      1.000000     47.900000
# 50%                    282.121944      1.000000     89.900000
# 75%                    389.514028      1.000000    159.900000
# max                   3504.386944     17.000000  13440.000000
#
#        avg_bask_price_x  pay_type_boleto_x  pay_type_credit_card_x  \
# count      96096.000000       96096.000000            96096.000000
# mean         143.745118           0.241321                0.913420
# std          241.697765           0.580622                0.746106
# min            0.000000           0.000000                0.000000
# 25%           46.900000           0.000000                1.000000
# 50%           89.000000           0.000000                1.000000
# 75%          153.780000           0.000000                1.000000
# max        13440.000000          20.000000               24.000000
#
#        pay_type_debit_card_x  pay_type_not_defined_x  pay_type_voucher_x  \
# count           96096.000000            96096.000000        96096.000000
# mean                0.017753                0.000031            0.067276
# std                 0.153889                0.005587            0.572776
# min                 0.000000                0.000000            0.000000
# 25%                 0.000000                0.000000            0.000000
# 50%                 0.000000                0.000000            0.000000
# 75%                 0.000000                0.000000            0.000000
# max                 7.000000                1.000000           75.000000
#
#          order_id_y       price_y  avg_bask_price_y  pay_type_boleto_y  \
# count  96096.000000  96096.000000      96096.000000       96096.000000
# mean       1.034809    148.535836        143.745118           0.241321
# std        0.214384    249.358758        241.697765           0.580622
# min        1.000000      0.000000          0.000000           0.000000
# 25%        1.000000     47.900000         46.900000           0.000000
# 50%        1.000000     89.900000         89.000000           0.000000
# 75%        1.000000    159.900000        153.780000           0.000000
# max       17.000000  13440.000000      13440.000000          20.000000
#
#        pay_type_credit_card_y  pay_type_debit_card_y  pay_type_not_defined_y  \
# count            96096.000000           96096.000000            96096.000000
# mean                 0.913420               0.017753                0.000031
# std                  0.746106               0.153889                0.005587
# min                  0.000000               0.000000                0.000000
# 25%                  1.000000               0.000000                0.000000
# 50%                  1.000000               0.000000                0.000000
# 75%                  1.000000               0.000000                0.000000
# max                 24.000000               7.000000                1.000000
#
#        pay_type_voucher_y
# count        96096.000000
# mean             0.067276
# std              0.572776
# min              0.000000
# 25%              0.000000
# 50%              0.000000
# 75%              0.000000
# max             75.000000

# %%
css3.to_csv(r'C:\Users\Maxime.ALTER\ProjetFinal\data\css3.csv', index = False)
