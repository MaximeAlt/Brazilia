# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
rd_test = pd.read_csv(r"C:\Users\Maxime.ALTER\ProjetFinal\data\rd_test1.csv")

# %%
rd_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96096 entries, 0 to 96095
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   customer_unique_id           96096 non-null  object
#  1   nb_order                     96096 non-null  int64
#  2   total_spend                  96096 non-null  float64
#  3   nb_review                    96096 non-null  int64
#  4   mean_review                  95380 non-null  float64
#  5   total_nb_product             96096 non-null  int64
#  6   total_nb_sellers             96096 non-null  int64
#  7   temps_approbation            95997 non-null  float64
#  8   erreur_estimation_livraison  93356 non-null  float64
#  9   temps_commande_livraison     93356 non-null  float64
#  10  temps_livraison_review       92753 non-null  float64
#  11  buy_freq                     96096 non-null  float64
# ...

# %%
rd_test = rd_test.drop(['customer_unique_id','nb_order','total_spend','nb_review','mean_review','total_nb_product','total_nb_sellers'], axis = 1)

# %%
lenght = len(rd_test)
rd_test.drop(rd_test.loc[(lenght/1000):lenght].index, inplace=True)

# %%
rd_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   temps_approbation            97 non-null     float64
#  1   erreur_estimation_livraison  95 non-null     float64
#  2   temps_commande_livraison     95 non-null     float64
#  3   temps_livraison_review       95 non-null     float64
#  4   buy_freq                     97 non-null     float64
#  5   delivery_distance            96 non-null     float64
#  6   ratio_transport_cost         97 non-null     float64
#  7   transport_cost_per_km        96 non-null     float64
# dtypes: float64(8)
# memory usage: 6.2 KB

# %%
rd_test_hm = sns.heatmap(rd_test, annot=True)

# %%
rd_test_hm.plot()
# Out:
# []

# %%
rd_test.to_csv(r"C:\Users\Maxime.ALTER\ProjetFinal\data\rd_test2.csv")
